# %% [markdown]
# # Trabajo integrador primera parte
# ## Delitos en la ciudad de Buenos Aires
# Este trabajo trata de analizar esta problemática con las herramientas vistas en el curso
# ![BuenosAires.jpg](attachment:BuenosAires.jpg)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:/Users/User/Desktop/Jupyter-Practice/DelitosArg/delitos2019.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117661 entries, 0 to 117660
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   117661 non-null  int64
#  1   fecha                117661 non-null  object
#  2   franja_horaria       117661 non-null  object
#  3   tipo_delito          117661 non-null  object
#  4   subtipo_delito       11676 non-null   object
#  5   cantidad_registrada  117661 non-null  float64
#  6   comuna               117064 non-null  float64
#  7   barrio               117064 non-null  object
#  8   lat                  117064 non-null  float64
#  9   long                 117064 non-null  float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 9.0+ MB

# %%
data["fecha"] = pd.to_datetime(data["fecha"])

# %%
data[data["fecha"].dt.year == 2019]["cantidad_registrada"].sum()
# Out:
# 117668.0

# %%
data["barrio"].value_counts().head(5)
# Out:
# Palermo        9559
# Balvanera      9239
# San Nicolás    6246
# Recoleta       5589
# Flores         5518
# Name: barrio, dtype: int64

# %%
data["barrio"].value_counts(ascending = True).head(5)
# Out:
# Puerto Madero    283
# Villa Real       343
# Versalles        392
# Agronomía        454
# Coghlan          476
# Name: barrio, dtype: int64

# %%
franja_horaria = []
delitos = {}
for n in range(0,24):
    cant = int(data[data["franja_horaria"] == str(n)]["cantidad_registrada"].sum())
    aux = (cant, n)
    delitos[n]= cant
    franja_horaria.append(aux)
franja_horaria.sort(reverse= True)
franja_horaria
# Out:
# [(7415, 18),
#  (7224, 19),
#  (6990, 20),
#  (6612, 17),
#  (6518, 16),
#  (6458, 14),
#  (6407, 12),
#  (6337, 21),
#  (6316, 15),
#  (6044, 13),
#  (5536, 10),
#  (5527, 11),
#  (5449, 22),
#  (5122, 8),
#  (4931, 9),
#  (4501, 23),
#  (3899, 7),
#  (3075, 0),
#  (2998, 6),
#  (2445, 1),
#  (2357, 5),
#  (1965, 2),
#  (1815, 4),
#  (1719, 3)]

# %%
pd.DataFrame(delitos)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8000\2011008555.py in <module>
# ----> 1 pd.DataFrame(delitos)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     500         # TODO: can we get rid of the dt64tz special case above?
#     501
# ...
